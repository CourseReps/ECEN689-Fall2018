# %% [markdown]
# # PART1 - white wine linear regression

# %%
import pandas as pd
import numpy as np

winequality_white_training_df = pd.read_csv('C:/Users/jatin/Desktop/chal4/ECEN689-Fall2018/Challenges/4Files/winequality-white-training.csv')
print(winequality_white_training_df.shape)

winequality_white_testing_df = pd.read_csv('C:/Users/jatin/Desktop/chal4/ECEN689-Fall2018/Challenges/4Files/winequality-white-testing.csv')
print(winequality_white_testing_df.shape)

winequality_white_prediction_df = pd.read_csv('C:/Users/jatin/Desktop/chal4/ECEN689-Fall2018/Challenges/4Files/winequality-white-sample.csv')
print(winequality_white_prediction_df.shape)
# Out:
# (3898, 13)
# (1000, 12)
# (1000, 2)

# %%
winequality_white_training_df.head()
winequality_white_training_df.columns
# Out:
# Index(['Id', 'fixed acidity', 'volatile acidity', 'citric acid',
#        'residual sugar', 'chlorides', 'free sulfur dioxide',
#        'total sulfur dioxide', 'density', 'pH', 'sulphates', 'alcohol',
#        'quality'],
#       dtype='object')

# %%
winequality_white_testing_df.head()
# Out:
#    Id  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0   0            7.0             0.310         0.31             9.1
# 1   1            7.3             0.155         0.49             1.3
# 2   2            6.0             0.260         0.24             1.3
# 3   3            6.6             0.180         0.26            17.3
# 4   4            6.2             0.290         0.26            13.1
#
#    chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0      0.036                 45.0                 140.0  0.99216  2.98
# 1      0.039                 34.0                 136.0  0.99260  3.14
# 2      0.053                 66.0                 150.0  0.99240  3.21
# 3      0.051                 17.0                 149.0  0.99840  3.00
# 4      0.046                 55.0                 204.0  0.99745  3.16
#
#    sulphates  alcohol
# 0       0.31     12.0
# 1       0.77     10.5
# 2       0.62     10.4
# 3       0.43      9.4
# 4       0.41      9.6

# %%
train_true_values = pd.DataFrame(winequality_white_training_df['quality'])
train_true_values.reset_index(drop=True, inplace=True)
train_true_values.head()
# Out:
#    quality
# 0        7
# 1        6
# 2        4
# 3        4
# 4        6

# %%
winequality_white_training_df.drop('quality', axis=1, inplace=True)
winequality_white_training_df =winequality_white_training_df.iloc[:,1:]
# alcohol, sulphates, citric_acid & fixed_acidity'
winequality_white_training_df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            8.7              0.23         0.32            13.4      0.044
# 1            5.0              0.27         0.40             1.2      0.076
# 2            8.0              0.16         0.36             1.5      0.033
# 3            5.8              0.28         0.35             2.3      0.053
# 4            7.1              0.14         0.33             1.0      0.104
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 35.0                 169.0  0.99975  3.12       0.47
# 1                 42.0                 124.0  0.99204  3.32       0.47
# 2                 14.0                 122.0  0.99410  3.20       0.39
# 3                 36.0                 114.0  0.99240  3.28       0.50
# 4                 20.0                  54.0  0.99057  3.19       0.64
#
#    alcohol
# 0      8.8
# 1     10.1
# 2     10.3
# 3     10.2
# 4     11.5

# %%
winequality_white_training_df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            8.7              0.23         0.32            13.4      0.044
# 1            5.0              0.27         0.40             1.2      0.076
# 2            8.0              0.16         0.36             1.5      0.033
# 3            5.8              0.28         0.35             2.3      0.053
# 4            7.1              0.14         0.33             1.0      0.104
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 35.0                 169.0  0.99975  3.12       0.47
# 1                 42.0                 124.0  0.99204  3.32       0.47
# 2                 14.0                 122.0  0.99410  3.20       0.39
# 3                 36.0                 114.0  0.99240  3.28       0.50
# 4                 20.0                  54.0  0.99057  3.19       0.64
#
#    alcohol
# 0      8.8
# 1     10.1
# 2     10.3
# 3     10.2
# 4     11.5

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression(normalize=False)

# %%
model.fit(winequality_white_training_df,train_true_values)
model.score(winequality_white_training_df,train_true_values)
# Out:
# 0.2751628369973135

# %%
winequality_white_testing_df = winequality_white_testing_df.iloc[:,1:]

# winequality_white_testing_df = winequality_white_testing_df.filter(['alcohol', 'sulphates', 'citric acid', 'volatile acidity','pH','total sulfur dioxide'],axis =1)
predictions = (model.predict(winequality_white_testing_df))
# print(predictions)
a = []
for i in predictions:
    for j in i:
        j = round(j)
        a.append(j)
model.get_params(deep= True)
# Out:
# {'copy_X': True, 'fit_intercept': True, 'n_jobs': 1, 'normalize': False}

# %%
ex_dic = {
    'id': [i for i in range(1000)],
    'quality': a
}
output  = pd.DataFrame(ex_dic, index=None)
output.head()
output.to_csv('C:/Users/jatin/Desktop/winequality-white-solution.csv',index=False)

# %%
white_wine_coef = model.coef_
white_wine_coef.reshape(-1)
white_wine_coef_pd.head()
# model.coef_
ex_dic_para= {
    'id': [i for i in range(11)],
    'parameters': [i for i in white_wine_coef.reshape(-1)]
}
white_wine_coef_pd = pd.DataFrame(ex_dic_para,index = None)
white_wine_coef_pd.T.to_csv('C:/Users/jatin/Desktop/winequality-white-parameters.csv',index=False)

# %%
np.array(white_wine_coef.reshape(-1).reshape((1,11)))
# Out:
# array([[ 6.19255832e-02, -1.83149523e+00,  3.15869785e-02,
#          7.87375964e-02, -4.89214094e-01,  3.58486991e-03,
#         -3.27934802e-04, -1.44989006e+02,  7.21238827e-01,
#          6.24079367e-01,  1.93168692e-01]])

# %% [markdown]
# # PART 3 Starts Here, using model to predict new test data from red wine

# %%
winequality_red_testing_df = pd.read_csv('C:/Users/jatin/Desktop/chal4/ECEN689-Fall2018/Challenges/4Files/winequality-red-testing.csv')
print(winequality_red_testing_df.shape)
# Out:
# (400, 12)

# %%
winequality_red_testing_df = winequality_red_testing_df.iloc[:,1:]

# %%
winequality_red_testing_df
# Out:
#      fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0              7.8             0.700         0.06            1.90      0.079
# 1              7.6             0.740         0.00            1.90      0.100
# 2              6.4             0.360         0.53            2.20      0.230
# 3              8.1             0.780         0.10            3.30      0.090
# 4              7.4             1.185         0.00            4.25      0.097
# 5              8.1             0.545         0.18            1.90      0.080
# 6              6.8             0.640         0.10            2.10      0.085
# 7              8.8             0.550         0.04            2.20      0.119
# 8              7.4             0.530         0.26            2.00      0.101
# 9              6.8             0.690         0.00            5.60      0.124
# 10             8.2             0.640         0.27            2.00      0.095
# 11             7.9             0.300         0.68            8.30      0.050
# 12             8.7             0.700         0.24            2.50      0.226
# 13             7.6             0.490         0.33            1.90      0.074
# 14             8.6             0.830         0.00            2.80      0.095
# 15             8.4             0.360         0.32            2.20      0.081
# 16             7.6             0.645         0.03            1.90      0.086
# 17             9.9             0.740         0.28            2.60      0.078
# 18             6.9             1.090         0.06            2.10      0.061
# 19             6.6             0.660         0.00            3.00      0.115
# 20             8.4             0.360         0.32            2.20      0.081
# 21             8.3             0.650         0.10            2.90      0.089
# 22             6.2             0.360         0.24            2.20      0.095
# 23             8.7             0.410         0.41            6.20      0.078
# 24            10.0             0.350         0.45            2.50      0.092
# 25             7.3             1.070         0.09            1.70      0.178
# 28                  15.0                    63  0.99640  3.00       1.59
# 29                  18.0                    34  0.99480  3.39       0.60
# ..                   ...                   ...      ...   ...        ...
# 370                  6.0                    10  0.99664  3.12       0.65
# 371                  9.0                    29  0.99416  3.28       0.49
# 372                  5.0                    15  0.99910  3.32       0.60
# 373                 11.0                    44  0.99888  3.31       0.55
# 374                 10.0                    31  0.99656  3.25       0.50
# 375                 20.0                    57  0.99598  3.60       0.74
# 376                  9.0                    17  0.99655  3.35       0.49
# 377                 25.0                    87  0.99975  3.24       0.62
# 378                 16.0                    47  0.99594  3.40       0.78
# 379                 23.0                    55  0.99471  3.78       0.64
# 380                 21.0                   101  1.00010  3.13       0.51
# 381                 12.0                    37  0.99690  3.25       0.58
# 382                 36.0                   121  0.99820  3.37       0.49
# 383                  6.0                    15  0.99840  3.01       0.83
# 384                 35.0                   152  0.99800  3.25       0.48
# 385                  7.0                    12  0.99587  3.34       0.39
# 386                 11.0                    47  0.99599  3.27       0.81
# 387                 20.0                    53  0.99620  3.42       0.65
# 388                  5.0                    11  0.99580  3.33       0.53
# 389                 27.0                    67  0.99648  3.60       0.59
# 390                 11.0                    34  0.99760  3.44       0.53
# 391                  5.0                    13  0.99472  3.52       0.56
# 392                  7.0                    22  0.99669  3.46       0.61
# 393                  7.0                    11  0.99562  3.45       0.58
# 394                  6.0                    39  0.99346  3.33       0.46
# 395                 22.0                    48  0.99494  3.30       0.84
# 396                 15.0                    38  0.99634  3.01       1.10
# 397                 18.0                    38  0.99518  3.16       0.85
# 398                  5.0                    62  0.99710  3.00       1.09
# 399                 16.0                    86  0.99743  3.53       0.57
#
#      alcohol
# 0       10.9
# 1       11.0
# 2       12.4
# 3        9.5
# 4       10.7
# 5        9.0
# 6       10.2
# 7       10.9
# 8        9.4
# 9       10.2
# 10       9.1
# 11      12.3
# 12       9.0
# 13       9.0
# 14      10.4
# 15      11.0
# 16      10.3
# 17       9.8
# 18      11.4
# 19      10.3
# 20      11.0
# 21       9.5
# 22      11.7
# 23      12.6
# 24       9.4
# 25       9.0
# 26       9.2
# 27       9.9
# 28       9.5
# 29      10.6
# ..       ...
# 370     11.8
# 371     11.3
# 372      9.0
# 373      9.5
# 374      9.8
# 375     11.7
# 376     10.8
# 377      9.7
# 378     11.3
# 379     12.3
# 380      9.5
# 381      9.5
# 382      9.4
# 383     11.8
# 384      9.4
# 385      9.5
# 386     11.0
# 387     11.0
# 388     10.3
# 389     11.1
# 390      9.5
# 391     11.4
# 392     10.2
# 393     11.3
# 394     11.9
# 395     11.5
# 396      9.4
# 397     11.1
# 398      9.3
# 399      9.7
#
# [400 rows x 11 columns]

# %%
red_predictions = (model.predict(winequality_red_testing_df))
# print(predictions)
b = []
for i in red_predictions:
    for j in i:
        j = round(j)
        b.append(j)
model.get_params(deep= True)
# Out:
# {'copy_X': True, 'fit_intercept': True, 'n_jobs': 1, 'normalize': False}

# %%
len(b)
# Out:
# 400

# %%
ex_dic = {
    'id': [i for i in range(400)],
    'quality': b
}
output  = pd.DataFrame(ex_dic, index=None)
output.head()
output.to_csv('C:/Users/jatin/Desktop/winequality-red-solution.csv',index=False)
