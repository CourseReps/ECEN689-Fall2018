# %% [markdown]
# # Challenge 3

# %%
import pandas as pd
import numpy as np
import sklearn
from sklearn.linear_model import Lasso
from sklearn.metrics import mean_squared_error
import warnings

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Loading train/test data sets

# %%
train_df = pd.read_csv('population_training_kaggle.csv', encoding='cp1252')
test_df  = pd.read_csv('population_testing_kaggle.csv', encoding='cp1252')

train_data = train_df
test_data = test_df

# %%
print(train_data.shape)
print(test_data.shape)
# Out:
# (40, 259)
# (17, 259)

# %% [markdown]
# #### Drop 'Id' column from data sets

# %%
train_data.drop(['Id'], axis=1,inplace=True)
train_data.head()
# Out:
#    Aruba  Afghanistan   Angola  Albania  Andorra  Arab World  \
# 0  54211      8996351  5643182  1608800    13411    92490932
# 1  55438      9166764  5753024  1659800    14375    95044497
# 2  56225      9345868  5866061  1711319    15370    97682294
# 3  56695      9533954  5980417  1762621    16412   100411076
# 4  57032      9731361  6093321  1814135    17469   103239902
#
#    United Arab Emirates  Argentina  Armenia  American Samoa    ...     \
# 0                 92634   20619075  1874120           20013    ...
# 1                101078   20953077  1941491           20486    ...
# 2                112472   21287682  2009526           21117    ...
# 3                125566   21621840  2077575           21882    ...
# 4                138529   21953929  2144998           22698    ...
#
#    Virgin Islands (U.S.)   Vietnam  Vanuatu       World   Samoa   Kosovo  \
# 0                  32500  32670629    63699  3032160395  108646   947000
# 1                  34300  33666772    65713  3073368588  112119   966000
# 2                  35000  34684165    67808  3126509808  115788   994000
# 3                  39800  35722091    69964  3191786431  119561  1022000
# 4                  40800  36780985    72131  3257459749  123354  1050000
#
#    Yemen, Rep.  South Africa   Zambia  Zimbabwe
# 0      5172135      17456855  3044846   3747369
# 1      5260501      17920673  3140264   3870756
# 2      5351799      18401608  3240587   3999419
# 3      5446063      18899275  3345145   4132756
# 4      5543339      19412975  3452942   4269863
#
# [5 rows x 258 columns]

# %%
#get list of Ids (for future reference)
id_list = test_data['Id']
test_data.drop(['Id'], axis=1, inplace=True)
test_data.head()
# Out:
#    Aruba  Afghanistan    Angola  Albania  Andorra  Arab World  \
# 0  90853     20093756  16440924  3089027    65390   283832016
# 1  92898     20966463  16983266  3060173    67341   289850357
# 2  94992     21979923  17572649  3051010    70049   296026575
# 3  97017     23064851  18203369  3039616    73182   302434519
# 4  98737     24118979  18865716  3026939    76244   309162029
#
#    United Arab Emirates  Argentina  Armenia  American Samoa    ...     \
# 0               3154925   37057452  3069588           57521    ...
# 1               3326032   37471509  3050655           58175    ...
# 2               3507232   37889370  3033897           58731    ...
# 3               3741932   38309379  3017806           59117    ...
# 4               4087931   38728696  3000612           59264    ...
#
#    Virgin Islands (U.S.)   Vietnam  Vanuatu       World   Samoa   Kosovo  \
# 0                 108642  80285562   185063  6121682741  174610  1700000
# 1                 108549  81139919   189290  6201340848  175566  1701154
# 2                 108510  81956496   193956  6280531847  176582  1702310
# 3                 108506  82747662   198964  6359901308  177662  1703466
# 4                 108467  83527678   204143  6439827446  178781  1704622
#
#    Yemen, Rep.  South Africa    Zambia  Zimbabwe
# 0     17874725      45728315  10531221  12222251
# 1     18390135      46385006  10824125  12366165
# 2     18919179      47026173  11120409  12500525
# 3     19462086      47648727  11421984  12633897
# 4     20017068      48247395  11731746  12777511
#
# [5 rows x 258 columns]

# %% [markdown]
# #### Define range of values to be used for alpha parameter of Lasso

# %%
alphas = 10**np.linspace(11,-2,200)*0.5
#alphas = 10**np.linspace(10,-2,5)*0.5
alphas
# Out:
#        3.22118175e+00, 2.77133226e+00, 2.38430585e+00, 2.05132905e+00,
#        1.76485365e+00, 1.51838556e+00, 1.30633761e+00, 1.12390292e+00,
#        9.66945875e-01, 8.31908443e-01, 7.15729469e-01, 6.15775302e-01,
#        5.29780090e-01, 4.55794415e-01, 3.92141103e-01, 3.37377203e-01,
#        2.90261276e-01, 2.49725256e-01, 2.14850235e-01, 1.84845635e-01,
#        1.59031285e-01, 1.36822000e-01, 1.17714321e-01, 1.01275097e-01,
#        8.71316693e-02, 7.49634216e-02, 6.44945131e-02, 5.54876248e-02,
#        4.77385806e-02, 4.10717179e-02, 3.53359064e-02, 3.04011213e-02,
#        2.61554965e-02, 2.25027884e-02, 1.93601939e-02, 1.66564739e-02,
#        1.43303381e-02, 1.23290554e-02, 1.06072589e-02, 9.12591747e-03,
#        7.85145062e-03, 6.75496761e-03, 5.81161234e-03, 5.00000000e-03])

# %% [markdown]
# ## Computation of coefficients

# %%
# define empty list for final coefficients
coef_array = []

#define regularization = Lasso
reg_fit = Lasso(fit_intercept=True, normalize=True)

#list for population prediction
pred_list=[]

for curr_country in range(0,258):
   
    # label for training would be current country population
    y_training = train_data[train_data.columns[curr_country]]
    
    # dropping current country from training set
    x_training = train_data.drop(train_data.columns[[curr_country]], axis=1, inplace=False)
    
    y_testing = test_data[test_data.columns[curr_country]]
    
    # dropping current country from testing set
    x_testing = test_data.drop(test_data.columns[[curr_country]], axis=1, inplace=False)
    
    # define minimum value for error (to be used in calculating best coefficients)
    minimum = float('inf')
    best_coef = 0
    #best_coef_arr = 0
    
    for a in alphas:
        # try for all values of alpha
        reg_fit.set_params(alpha = a)
        
        # fit for training data
        reg_fit.fit(x_training, y_training)
        
        # get prediction data
        prediction = reg_fit.predict(x_testing)
        
        # get error between predicted and actual value
        error = mean_squared_error(prediction,y_testing)
        
        # count number of non-zero coeff (we want 5)
        count = np.count_nonzero(reg_fit.coef_)
        
        # compute best coefficients only if 5 possible
        if count == 5:
            # check if error less than previously computed min value
            if error < minimum:
                
                # get coefficients
                best_coef = reg_fit.coef_
                
                minimum = error
                
                # predict for these coefficients
                prediction = reg_fit.predict(x_testing)
        
                # make current country coefficient to 0
                loc_arr = best_coef
                # insert 0 at current location
                best_coef_arr = np.insert(loc_arr,curr_country,0)
    
    # append best coeff and predicted values
    coef_array.append(best_coef_arr) 
    pred_list.append(prediction)

# %% [markdown]
# ### Getting parameters

# %%
coef_final = np.array(coef_array)
print(coef_final.shape)

# %%
# get list of countries
countries = train_df.columns

# %%
# convert to pd datafrane
df_coef = pd.DataFrame(data=coef_array, columns=countries, index=countries)

# take transpose for accurate matching
df_final_coef = df_coef.transpose()

# dump to csv
df_final_coef.to_csv('population_parameters_1.csv', encoding='cp1252')

# %% [markdown]
# ### Getting predictions

# %%
pred_array = np.array(pred_list)
print(pred_array.shape)

# %%
# convert to pd dataframe
df = pd.DataFrame(data=pred_list)

# take transpose for accurate matching
df2 = df.transpose()

# create empty df for storing final values
df_final = pd.DataFrame(id_list, columns=['Id'])

#add cols for all other countries
for i in range(len(test_df.columns)):
    colname = test_df.columns[i]
    df_final[colname] = df2[i]

print(df_final.shape)

# %%
df_final.head(5)

# %%
# dump to csv
df_final.to_csv('population_prediction_1.csv',encoding='cp1252', index=False)
