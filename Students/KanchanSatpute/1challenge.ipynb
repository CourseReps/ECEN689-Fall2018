# %% [markdown]
# # Challenge 1
#
# ## Reading Materials
#
# ### Required Reading
# Due: September 6, 2018
#
#  * Understanding Machine Learning from Theory to Algorithms, S. Shalev-Shwartz and S. Ben-David
#    * **Chapter 1**: A gentle start
#    * **Chapter 9**: Linear predictors
#
#
# ### [Kaggle Tutorials](https://www.kaggle.com/learn/overview)
# Due: September 6, 2018
#
#  * __Complete__ [Python course](https://www.kaggle.com/learn/python), if needed
#  * __Complete__ [Pandas course](https://www.kaggle.com/learn/pandas), if needed
#
#
# ## Activity 1
# Due: September 6, 2018
#
# In Activity 1, you are tasked with estimating the mean and variance of a series of data sets, two parameters for every row.
# Each student has their own file, and should work in place.
# ```python
# student_identity = 'netid'
# filename = '1challenge1activity_' + student_identity + '.csv'
# ```
#
# ### Deliverables
#  1. Fill column ```Mean``` and ```Variance```.
#  2. Commit your change on Git.
#
# ### Metric
#  * Average $L_2$ norm between the true and estimated parameters.

# %%
import pandas as pd
import numpy as np

student_identity = 'kanch_sat'
filename = '1challenge1activity_' + student_identity + '.csv'
sample_df = pd.read_csv('C:/Users/asus/Documents/TAMU/Fall-18/ECEN-689/Github/ECEN689-Fall2018/Challenges/1Files/' + filename)

# %%
sample_df.iloc[:, 3:].head()
# Out:
#    Sample 0  Sample 1  Sample 2  Sample 3  Sample 4  Sample 5  Sample 6  \
# 0 -0.356745 -0.183028 -0.382286 -0.022849  1.256347  0.801757  0.473417
# 1  1.667534 -0.821310  0.638524 -0.037975  0.634775  1.454144  1.670511
# 2  2.160183  2.099219 -0.849233 -0.301538 -0.463306  0.242122  0.729704
# 3  0.875217 -0.242141  0.645199  0.928085  0.499258  1.175876 -0.021953
# 4 -0.561347  1.331031 -0.425707 -0.459405 -0.342327  0.343183  1.091081
#
#    Sample 7  Sample 8  Sample 9  Sample 10  Sample 11
# 0 -1.241543 -1.327338  0.486276   0.220107  -0.794989
# 1  1.367984  1.020593 -0.728912   1.117575  -0.911815
# 2  1.026922 -1.025407  0.556614   1.124122  -0.169490
# 3  0.407244  0.187456  0.767720  -1.300919   1.609959
# 4  0.730526  0.574267 -0.408223  -0.224992  -0.893110

# %%
sample_df["Mean"] = sample_df.iloc[:, 3:].mean(axis=1)

# %%
sample_df["Variance"] = sample_df.iloc[:, 3:].var(axis=1)

# %%
sample_df.head()
# Out:
#    Unnamed: 0      Mean  Variance  Sample 0  Sample 1  Sample 2  Sample 3  \
# 0           0 -0.089240  0.625217 -0.356745 -0.183028 -0.382286 -0.022849
# 1           1  0.589302  0.957255  1.667534 -0.821310  0.638524 -0.037975
# 2           2  0.427493  1.109655  2.160183  2.099219 -0.849233 -0.301538
# 3           3  0.460917  0.569099  0.875217 -0.242141  0.645199  0.928085
# 4           4  0.062915  0.521392 -0.561347  1.331031 -0.425707 -0.459405
#
#    Sample 4  Sample 5  Sample 6  Sample 7  Sample 8  Sample 9  Sample 10  \
# 0  1.256347  0.801757  0.473417 -1.241543 -1.327338  0.486276   0.220107
# 1  0.634775  1.454144  1.670511  1.367984  1.020593 -0.728912   1.117575
# 2 -0.463306  0.242122  0.729704  1.026922 -1.025407  0.556614   1.124122
# 3  0.499258  1.175876 -0.021953  0.407244  0.187456  0.767720  -1.300919
# 4 -0.342327  0.343183  1.091081  0.730526  0.574267 -0.408223  -0.224992
#
#    Sample 11
# 0  -0.794989
# 1  -0.911815
# 2  -0.169490
# 3   1.609959
# 4  -0.893110

# %%
sample_df.to_csv('C:/Users/asus/Documents/1challenge1activity_kanch_sat.csv')

# %%
sample_df.to_csv('C:/Users/asus/Documents/TAMU/Fall-18/ECEN-689/Github/ECEN689-Fall2018/Challenges/1Files/1challenge1activity_kanch_sat.csv')
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-33-7fa7141214b4> in <module>()
# ----> 1 sample_df.to_csv('C:/Users/asus/Documents/TAMU/Fall-18/ECEN-689/Github/ECEN689-Fall2018/Challenges/1Files/1challenge1activity_kanch_sat.csv')
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, tupleize_cols, date_format, doublequote, escapechar, decimal)
#    1743                                  doublequote=doublequote,
#    1744                                  escapechar=escapechar, decimal=decimal)
# -> 1745         formatter.save()
#    1746
#    1747         if path_or_buf is None:
#
# ~\Anaconda3\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     134             f, handles = _get_handle(self.path_or_buf, self.mode,
#     135                                      encoding=encoding,
# --> 136                                      compression=None)
#     137             close = True if self.compression is None else False
#     138
#
# ~\Anaconda3\lib\site-packages\pandas\io\common.py in _get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text)
#     398         elif encoding:
#     399             # Python 3 and encoding
# --> 400             f = open(path_or_buf, mode, encoding=encoding)
#     401         elif is_text:
#     402             # Python 3 and no explicit encoding
#
# PermissionError: [Errno 13] Permission denied: 'C:/Users/asus/Documents/TAMU/Fall-18/ECEN-689/Github/ECEN689-Fall2018/Challenges/1Files/1challenge1activity_kanch_sat.csv'
