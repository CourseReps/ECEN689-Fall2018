# %%
import numpy as np
import pandas as pd

# %%
sample_df=pd.read_csv("OneDrive/Documents/GitHub/ECEN689-Fall2018/Challenges/1Files/1challenge1activity_vaishno-gre1966.csv")
sample_df['Mean']=sample_df.loc[:,'Sample 0':'Sample 11'].mean(axis=1)
sample_df['Variance']=sample_df.loc[:,'Sample 0':'Sample 11'].var(axis=1)
print (sample_df)
sample_df.to_csv('1challenge1activity_vaishno-gre1966.csv',sep=',')
# Out:
#     Unnamed: 0      Mean  Variance  Sample 0  Sample 1  Sample 2  Sample 3  \
# 0            0  0.256986  0.717279  0.292183 -1.354810  1.464048  0.935360
# 1            1 -0.047003  1.490268  1.413232  1.858712  0.368239  0.157633
# 2            2 -0.273816  0.992736 -0.405519 -0.533892  0.048314 -2.442918
# 3            3 -0.259604  1.319781  1.376699 -0.715576  0.659382  0.041836
# 4            4 -0.301742  0.587361 -0.380475  1.211619 -1.135575 -0.707213
# 5            5  0.050823  1.952373 -0.815873 -1.322781  1.064992  2.274291
# 6            6  0.647223  0.724984  1.060379  1.509441  0.472533 -0.712670
# 7            7  1.584318  0.824365  1.984021  2.230466  0.842640  3.343034
# 8            8  1.569173  1.220398  1.277947 -0.017792  0.560749  1.627219
# 9            9 -0.814072  1.042249  0.248044 -0.506345 -1.126641 -0.762256
# 10          10 -1.902375  0.871998 -2.323154 -1.485392 -1.726267 -1.722521
# ...

# %%
pwd
# Out:
# 'C:\\Users\\divya'
